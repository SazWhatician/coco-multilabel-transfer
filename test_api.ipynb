# %% [markdown]
# ## Run this to Detect a Car

# %%
# !pip install requests
from PIL import Image
import matplotlib.pyplot as plt
import requests
import json

url = "http://127.0.0.1:8000/enhanced-vision"

with open("img123.jpg", "rb") as f:
    response = requests.post(url, files={"file": ("img123.jpg", f, "image/jpeg")})

print("Status Code:", response.status_code)
print("\nJSON Response:")
print(json.dumps(response.json(), indent=2))



img = Image.open("img123.jpg")
plt.imshow(img)
plt.axis("off")
plt.title("Carrrrr")
plt.show()
# Out:
# ...
# Status Code: 200
#
# JSON Response:
# {
#   "cnn_predictions": {
#     "car": 0.9937,
#     "person": 0.3785
#   },
#   "multimodal_enhancement": "The image shows a white sports car with Japanese writing and a logo on the side. The car features a distinctive design with a large front bumper, a spoiler on the back, and black wheels with \"Bridgestone\" written on the tires.\n\nThe CNN model's predictions are partially accurate, as the image does contain a car (with 99% confidence), but there is no person visible. \n\nThe CNN model may have missed the car's tires and spoiler, which are important features of the vehicle.",
# ...

# %%
data = response.json()

print("CNN Predictions:")
for label, score in data["cnn_predictions"].items():
    print(f"  {label}: {score:.2%}")

print("\nMultimodal Enhancement:")
print(data["multimodal_enhancement"])

print("\nFinal Enhanced Response:")
print(data["final_enhanced_response"])

# %% [markdown]
# ## Run this to see the GOAT

# %%
# !pip install requests
from PIL import Image
import matplotlib.pyplot as plt
import requests
import json

url = "http://127.0.0.1:8000/enhanced-vision"

with open("img_02.jpg", "rb") as f:
    response = requests.post(url, files={"file": ("img_02.jpg", f, "image/jpeg")})

print("Status Code:", response.status_code)
print("\nJSON Response:")
print(json.dumps(response.json(), indent=2))



img = Image.open("img_02.jpg")
plt.imshow(img)
plt.axis("off")
plt.title("GOAT fr")
plt.show()
# Out:
# ...
# Status Code: 200
#
# JSON Response:
# {
#   "cnn_predictions": {
#     "person": 0.984,
#     "bottle": 0.4105,
#     "tvmonitor": 0.335
#   },
#   "multimodal_enhancement": "The image depicts Kanye West on the cover of a Japanese magazine, wearing a striped shirt and a gold chain with a pendant. He is also wearing a white Casio G-Shock watch on his left wrist.\n\nThe CNN model's predictions are partially accurate: person (98% accurate), but there is no visible bottle or tvmonitor in the image.\n\nThe CNN model missed important objects such as the magazine title in large red Japanese characters, a smaller text at the top reading \"HOW THE G-SHOCK BECAME A FIXTURE ON CELEB WRISTS\", and several other Japanese characters and text throughout the image.",
# ...

# %%
data = response.json()

print("CNN Predictions:")
for label, score in data["cnn_predictions"].items():
    print(f"  {label}: {score:.2%}")

print("\nMultimodal Enhancement:")
print(data["multimodal_enhancement"])

print("\nFinal Enhanced Response:")
print(data["final_enhanced_response"])
# Out:
# CNN Predictions:
#   person: 98.40%
#   bottle: 41.05%
#   tvmonitor: 33.50%
#
# Multimodal Enhancement:
# The image depicts Kanye West on the cover of a Japanese magazine, wearing a striped shirt and a gold chain with a pendant. He is also wearing a white Casio G-Shock watch on his left wrist.
#
# The CNN model's predictions are partially accurate: person (98% accurate), but there is no visible bottle or tvmonitor in the image.
#
# The CNN model missed important objects such as the magazine title in large red Japanese characters, a smaller text at the top reading "HOW THE G-SHOCK BECAME A FIXTURE ON CELEB WRISTS", and several other Japanese characters and text throughout the image.
#
# Final Enhanced Response:
# CNN detected: person(98%), bottle(41%), tvmonitor(34%). Multimodal LLM analysis: The image depicts Kanye West on the cover of a Japanese magazine, wearing a striped shirt and a gold chain with a pendant. He is also wearing a white Casio G-Shock watch on his left wrist.
#
# ...

# %% [markdown]
# ## More confusing Car image

# %%
# !pip install requests
from PIL import Image
import matplotlib.pyplot as plt
import requests
import json

url = "http://127.0.0.1:8000/enhanced-vision"

with open("car23.jpg", "rb") as f:
    response = requests.post(url, files={"file": ("car23.jpg", f, "image/jpeg")})

print("Status Code:", response.status_code)
print("\nJSON Response:")
print(json.dumps(response.json(), indent=2))



img = Image.open("car23.jpg")
plt.imshow(img)
plt.axis("off")
plt.title("ok")
plt.show()
# Out:
# ...
# Status Code: 200
#
# JSON Response:
# {
#   "cnn_predictions": {
#     "car": 0.9796
#   },
#   "multimodal_enhancement": "The image displays a sleek black sports car with red accents driving through a field of tall, golden wheat or grass. The car, which appears to be a futuristic design, has the word \"PORSCHE\" written in white on its back. The vehicle is positioned in the middle of the frame, facing away from the viewer.\n\nThe CNN model's prediction of a car with a confidence level of 98% is accurate, as a car is indeed present in the image. \nOther important objects detected in the image include a hill and a clear blue sky.",
# ...

# %%
data = response.json()

print("CNN Predictions:")
for label, score in data["cnn_predictions"].items():
    print(f"  {label}: {score:.2%}")

print("\nMultimodal Enhancement:")
print(data["multimodal_enhancement"])

print("\nFinal Enhanced Response:")
print(data["final_enhanced_response"])
# Out:
# CNN Predictions:
#   person: 98.40%
#   bottle: 41.05%
#   tvmonitor: 33.50%
#
# Multimodal Enhancement:
# 1. The image depicts Kanye West on the cover of a magazine, wearing a striped shirt, a gold chain with a pendant, and a white Casio G-Shock watch. The background features Japanese text and various graphics.
#
# 2. The CNN predictions are partially accurate:
# - **Person:** 98% accurate, as Kanye West is prominently featured.
# - **Bottle:** Not present in the image (41% prediction is incorrect).
# - **TV monitor:** Not present in the image (34% prediction is incorrect).
#
# 3. Important objects the CNN may have missed include the magazine title in large red letters, a smaller image of Kanye West, and the Casio G-Shock branding.
#
# Final Enhanced Response:
# ...
